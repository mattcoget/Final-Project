# %%
import pandas as pd
import numpy as np
import os

# %%
os.chdir('C:\\Users\\mcoge\\Satellite project')

# %%
os.listdir()
# Out:
# ['budget.xlsx',
#  'budget_cleaned.csv',
#  'satellites.xlsx',
#  'satellites_cleaned.csv',
#  'Screenshot_2021-01-16 TR Dashboard - mattcoget gmail com - Gmail.png']

# %%
budget=pd.read_excel('budget.xlsx')

# %%
satellites=pd.read_excel('satellites.xlsx')

# %%
satellites.head()
# Out:
#   satellite_Name  Launch year Launch status        Application  \
# 0         DMC-3A         2015      Launched  Earth Observation
# 1         DMC-3B         2015      Launched  Earth Observation
# 2         DMC-3C         2015      Launched  Earth Observation
# 3        SSTL-S1         2018      Launched  Earth Observation
# 4         VRSS-1         2012      Launched  Earth Observation
#
#   operator_status operator_query.country global_regional_distribution  \
# 0           Civil                  China                         Asia
# 1           Civil                  China                         Asia
# 2           Civil                  China                         Asia
# 3           Civil                  China                         Asia
# 4           Civil          Venezuela, RB  Latin America and Caribbean
#
#   mass_range_kg price_range_m$
# 0       <500 kg       51-200M$
# 1       <500 kg       51-200M$
# 2       <500 kg       51-200M$
# 3       <500 kg       51-200M$
# ...

# %%
satellites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2499 entries, 0 to 2498
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   satellite_Name                2499 non-null   object
#  1   Launch year                   2499 non-null   int64
#  2   Launch status                 2499 non-null   object
#  3   Application                   2499 non-null   object
#  4   operator_status               2499 non-null   object
#  5   operator_query.country        2499 non-null   object
#  6   global_regional_distribution  2499 non-null   object
#  7   mass_range_kg                 2499 non-null   object
#  8   price_range_m$                2499 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 175.8+ KB

# %%
satellites.isna().sum()
# Out:
# satellite_Name                  0
# Launch year                     0
# Launch status                   0
# Application                     0
# operator_status                 0
# operator_query.country          0
# global_regional_distribution    0
# mass_range_kg                   0
# price_range_m$                  0
# dtype: int64

# %%
satellites['price_range_m$'].value_counts()
# Out:
# <50 M$        945
# 51-200M$      750
# 201-500 M$    451
# TBD           183
# >500 M$       170
# Name: price_range_m$, dtype: int64

# %%
satellites.nunique()
# Out:
# satellite_Name                  2380
# Launch year                       20
# Launch status                      5
# Application                       10
# operator_status                    2
# operator_query.country            76
# global_regional_distribution       6
# mass_range_kg                      4
# price_range_m$                     5
# dtype: int64

# %%
satellites.satellite_Name.value_counts()
# Out:
# Forecast single sat           55
# SSA european constellation    19
# US tactical comsat            14
# Small military mission        13
# Sfera EO                       6
#                               ..
# Beidou 3G 5 / 2Upgrade         1
# ASCENDS                        1
# Yaogan 9C / JB-8 1C            1
# Yaogan 8 / JB-9 1              1
# Sich 2-M                       1
# Name: satellite_Name, Length: 2380, dtype: int64

# %%
satellites.Application.value_counts()
# Out:
# Earth Observation     705
# Telecom               607
# Security              253
# Navigation            251
# Manned spaceflight    183
# Technology            163
# Information           148
# Science               104
# Exploration            84
# In Orbit Servicing      1
# Name: Application, dtype: int64

# %%
satellites[satellites.satellite_Name=='SSA european constellation']
# Out:
#                  satellite_Name  Launch year   Launch status Application  \
# 908  SSA european constellation         2025  To be launched    Security
# 909  SSA european constellation         2025  To be launched    Security
# 910  SSA european constellation         2025  To be launched    Security
# 911  SSA european constellation         2025  To be launched    Security
# 912  SSA european constellation         2025  To be launched    Security
# 913  SSA european constellation         2025  To be launched    Security
# 914  SSA european constellation         2024  To be launched    Security
# 915  SSA european constellation         2024  To be launched    Security
# 916  SSA european constellation         2024  To be launched    Security
# 917  SSA european constellation         2024  To be launched    Security
# 918  SSA european constellation         2024  To be launched    Security
# 919  SSA european constellation         2024  To be launched    Security
# ...

# %%
budget.head()
# Out:
#   application  year       value  region country_code  country program_type  \
# 0       Total  2019  195.432000  Europe          BEL  Belgium        Civil
# 1       Total  2020  171.600069  Europe          BEL  Belgium        Civil
# 2       Total  2019  220.230630  Europe          BEL  Belgium        Civil
# 3       Total  2020  193.374633  Europe          BEL  Belgium        Civil
# 4       Total  2019   54.274739  Europe          AUT  Austria        Civil
#
#   program_name     unit currency
# 0          ESA  million      EUR
# 1          ESA  million      EUR
# 2          ESA  million      USD
# 3          ESA  million      USD
# 4          ESA  million      EUR

# %%
budget.columns
# Out:
# Index(['application', 'year', 'value', 'region', 'country_code', 'country',
#        'program_type', 'program_name', 'unit', 'currency'],
#       dtype='object')

# %%
budget.groupby(['year','country','program_name'])['value'].sum().to_frame().head(50)
# Out:
#                                               value
# year country          program_name
# 1999 Algeria          National program     0.000000
#      Angola           National program     0.000000
#      Argentina        National program    20.576574
#      Australia        National program    55.182698
#      Austria          ESA                  0.000000
#                       Eumetsat            14.467390
#                       National program     8.267080
#      Azerbaijan       National program     0.000000
#      Bahrain          National program     0.000000
#      Bangladesh       National program     0.000000
#      Belarus          National program     0.000000
#      Belgium          ESA                307.714535
#                       Eumetsat            18.600930
#                       National program    20.667700
#      Bolivia          National program     0.000000
#      Brazil           National program   205.899610
# ...

# %%
satellites['Launch status'].value_counts()
# Out:
# To be launched            1267
# Launched                  1147
# Launch failure              42
# To be Launched              32
# Partial launch failure      11
# Name: Launch status, dtype: int64

# %%
satellites[satellites['Launch year']<2021]
# Out:
#      satellite_Name  Launch year           Launch status        Application  \
# 0            DMC-3A         2015                Launched  Earth Observation
# 1            DMC-3B         2015                Launched  Earth Observation
# 2            DMC-3C         2015                Launched  Earth Observation
# 3           SSTL-S1         2018                Launched  Earth Observation
# 4            VRSS-1         2012                Launched  Earth Observation
# ...             ...          ...                     ...                ...
# 2491          RS 50         2018                Launched         Technology
# 2492    MicroDragon         2019                Launched         Technology
# 2493      Yahsat-1A         2011                Launched            Telecom
# 2494      Yahsat-1B         2012                Launched            Telecom
# 2496       Al Yah 3         2018  Partial launch failure            Telecom
#
# ...

# %%
satellites['Launch year'].max()
# Out:
# 2028

# %%
satellites.shape
# Out:
# (2499, 9)

# %%
satellites.drop_duplicates()
# Out:
#      satellite_Name  Launch year           Launch status        Application  \
# 0            DMC-3A         2015                Launched  Earth Observation
# 1            DMC-3B         2015                Launched  Earth Observation
# 2            DMC-3C         2015                Launched  Earth Observation
# 3           SSTL-S1         2018                Launched  Earth Observation
# 4            VRSS-1         2012                Launched  Earth Observation
# ...             ...          ...                     ...                ...
# 2494      Yahsat-1B         2012                Launched            Telecom
# 2495    Thuraya 3+R         2024          To be launched            Telecom
# 2496       Al Yah 3         2018  Partial launch failure            Telecom
# 2497    Yahsat-1A+R         2026          To be launched            Telecom
# 2498    Yahsat-1B+R         2028          To be launched            Telecom
#
# ...

# %%
satellites[satellites.satellite_Name=='Sfera EO']
# Out:
#      satellite_Name  Launch year   Launch status        Application  \
# 1965       Sfera EO         2023  To be launched  Earth Observation
# 1966       Sfera EO         2023  To be launched  Earth Observation
# 1967       Sfera EO         2023  To be launched  Earth Observation
# 1968       Sfera EO         2027  To be launched  Earth Observation
# 1969       Sfera EO         2027  To be launched  Earth Observation
# 1970       Sfera EO         2027  To be launched  Earth Observation
#
#      operator_status operator_query.country global_regional_distribution  \
# 1965           Civil     Russian Federation      Russia and Central Asia
# 1966           Civil     Russian Federation      Russia and Central Asia
# 1967           Civil     Russian Federation      Russia and Central Asia
# 1968           Civil     Russian Federation      Russia and Central Asia
# 1969           Civil     Russian Federation      Russia and Central Asia
# ...

# %%
satellites[satellites.satellite_Name=='Sfera IoT']
# Out:
#      satellite_Name  Launch year   Launch status  Application operator_status  \
# 1971      Sfera IoT         2023  To be launched  Information           Civil
# 1972      Sfera IoT         2023  To be launched  Information           Civil
# 1973      Sfera IoT         2027  To be launched  Information           Civil
# 1974      Sfera IoT         2027  To be launched  Information           Civil
# 1975      Sfera IoT         2027  To be launched  Information           Civil
#
#      operator_query.country global_regional_distribution mass_range_kg  \
# 1971     Russian Federation      Russia and Central Asia       <500 kg
# 1972     Russian Federation      Russia and Central Asia       <500 kg
# 1973     Russian Federation      Russia and Central Asia       <500 kg
# 1974     Russian Federation      Russia and Central Asia       <500 kg
# 1975     Russian Federation      Russia and Central Asia       <500 kg
#
#      price_range_m$
# 1971         <50 M$
# 1972         <50 M$
# ...

# %%
satellites.groupby(['satellite_Name'])['Application'].count().sort_values(ascending=False)[:20]
# Out:
# satellite_Name
# Forecast single sat                       55
# SSA european constellation                19
# US tactical comsat                        14
# Small military mission                    13
# Sfera EO                                   6
# Sfera IoT                                  5
# Gaofen-5 +R                                3
# Government Moon mission forecast China     3
# Hyperspectral US Military                  3
# Shen Tong 2C+R                             2
# Xingyun 165                                2
# Xingyun 164                                2
# Xingyun 163                                2
# Insat 3DR                                  2
# Arktika-M N5                               2
# Tianzhou 9                                 2
# HY-3C / Hai Yang-3C                        1
# HY-3B / Hai Yang-3B                        1
# Hainan-1-13                                1
# Hainan-1-12                                1
# Name: Application, dtype: int64

# %%
budget.isna().sum()
# Out:
# application        0
# year               0
# value              0
# region          1918
# country_code       0
# country            0
# program_type       0
# program_name       0
# unit               0
# currency           0
# dtype: int64

# %%
budget[budget.region.isna()].country.value_counts()
# Out:
# Canada           1412
# United States     506
# Name: country, dtype: int64

# %%
budget.region.value_counts()
# Out:
# Europe    40804
# MEA       19360
# Asia      18436
# LATAM     10164
# CIS        6776
# Name: region, dtype: int64

# %%
budget.to_csv('budget.csv', index=False)

# %%
pd.read_csv('budget.csv')
# Out:
#              application  year       value  region country_code   country  \
# 0                  Total  2019  195.432000  Europe          BEL   Belgium
# 1                  Total  2020  171.600069  Europe          BEL   Belgium
# 2                  Total  2019  220.230630  Europe          BEL   Belgium
# 3                  Total  2020  193.374633  Europe          BEL   Belgium
# 4                  Total  2019   54.274739  Europe          AUT   Austria
# ...                  ...   ...         ...     ...          ...       ...
# 97453         Technology  2020    0.000000  Europe          EUM  Eumetsat
# 97454  Human Spaceflight  2020    0.000000  Europe          EUM  Eumetsat
# 97455    Launch vehicles  2020    0.000000  Europe          EUM  Eumetsat
# 97456     Space security  2020    0.000000  Europe          EUM  Eumetsat
# 97457              Other  2020    0.000000  Europe          EUM  Eumetsat
#
#       program_type      program_name     unit currency
# ...

# %%
budget.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97458 entries, 0 to 97457
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   application   97458 non-null  object
#  1   year          97458 non-null  int64
#  2   value         97458 non-null  float64
#  3   region        95540 non-null  object
#  4   country_code  97458 non-null  object
#  5   country       97458 non-null  object
#  6   program_type  97458 non-null  object
#  7   program_name  97458 non-null  object
#  8   unit          97458 non-null  object
#  9   currency      97458 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 7.4+ MB

# %%
china=budget[budget.country=='China']
china[china.year==2020]
# Out:
#                          application  year         value region country_code  \
# 14155            Internal operations  2020   1784.329718   Asia          CHN
# 14156             Telecommunications  2020   2391.232658   Asia          CHN
# 14157                     Navigation  2020   4275.000000   Asia          CHN
# 14158              Earth Observation  2020   7283.847252   Asia          CHN
# 14159                    Meteorology  2020   2967.547591   Asia          CHN
# 14160  Space Science and exploration  2020   6540.524403   Asia          CHN
# 14161                     Technology  2020      0.000000   Asia          CHN
# 14162              Human Spaceflight  2020      0.000000   Asia          CHN
# 14163                Launch vehicles  2020      0.000000   Asia          CHN
# 14164                 Space security  2020     65.854080   Asia          CHN
# 14165                          Other  2020      0.000000   Asia          CHN
# ...

# %%
budget.query('currency=="USD"')
# Out:
#              application  year       value  region country_code   country  \
# 2                  Total  2019  220.230630  Europe          BEL   Belgium
# 3                  Total  2020  193.374633  Europe          BEL   Belgium
# 6                  Total  2019   61.161734  Europe          AUT   Austria
# 7                  Total  2020   50.245259  Europe          AUT   Austria
# 10                 Total  2019    1.513415  Europe          BGR  Bulgaria
# ...                  ...   ...         ...     ...          ...       ...
# 97453         Technology  2020    0.000000  Europe          EUM  Eumetsat
# 97454  Human Spaceflight  2020    0.000000  Europe          EUM  Eumetsat
# 97455    Launch vehicles  2020    0.000000  Europe          EUM  Eumetsat
# 97456     Space security  2020    0.000000  Europe          EUM  Eumetsat
# 97457              Other  2020    0.000000  Europe          EUM  Eumetsat
#
#       program_type      program_name     unit currency
# ...

# %%
satellites
# Out:
#      satellite_Name  Launch year           Launch status        Application  \
# 0            DMC-3A         2015                Launched  Earth Observation
# 1            DMC-3B         2015                Launched  Earth Observation
# 2            DMC-3C         2015                Launched  Earth Observation
# 3           SSTL-S1         2018                Launched  Earth Observation
# 4            VRSS-1         2012                Launched  Earth Observation
# ...             ...          ...                     ...                ...
# 2494      Yahsat-1B         2012                Launched            Telecom
# 2495    Thuraya 3+R         2024          To be launched            Telecom
# 2496       Al Yah 3         2018  Partial launch failure            Telecom
# 2497    Yahsat-1A+R         2026          To be launched            Telecom
# 2498    Yahsat-1B+R         2028          To be launched            Telecom
#
# ...

# %%
budget[budget.currency=='USD'].shape[0]/budget.shape[0]
# Out:
# 0.5050791110016623

# %%
budget.year.value_counts().sort_index()
# Out:
# 1999    4479
# 2000    4479
# 2001    4479
# 2002    4479
# 2003    4479
# 2004    4479
# 2005    4479
# 2006    4479
# 2007    4479
# 2008    4479
# 2009    4479
# 2010    4479
# 2011    4479
# 2012    4479
# 2013    4479
# 2014    4479
# 2015    4479
# 2016    4479
# 2017    4479
# 2018    4479
# 2019    3939
# 2020    3939
# Name: year, dtype: int64

# %%
budget_dollar=budget[budget.currency=='USD']

# %%
budget[budget.country_code=='USA']
# Out:
#                application  year     value region country_code        country  \
# 94972  Internal operations  1999     0.000    NaN          USA  United States
# 94973   Telecommunications  1999    97.000    NaN          USA  United States
# 94974           Navigation  1999     0.000    NaN          USA  United States
# 94975    Earth Observation  1999  1414.000    NaN          USA  United States
# 94976          Meteorology  1999     0.000    NaN          USA  United States
# ...                    ...   ...       ...    ...          ...            ...
# 95473           Technology  2020  2056.072    NaN          USA  United States
# 95474    Human Spaceflight  2020     0.000    NaN          USA  United States
# 95475      Launch vehicles  2020  1836.804    NaN          USA  United States
# 95476       Space security  2020   725.491    NaN          USA  United States
# 95477                Other  2020   230.362    NaN          USA  United States
#
# ...

# %%
budget_dollar.shape[0]/budget.shape[0]
# Out:
# 0.5050791110016623

# %%
budget_local_currency=budget[~(budget.currency=='USD')]

# %%
budget_local_currency
# Out:
#              application  year       value  region country_code   country  \
# 0                  Total  2019  195.432000  Europe          BEL   Belgium
# 1                  Total  2020  171.600069  Europe          BEL   Belgium
# 4                  Total  2019   54.274739  Europe          AUT   Austria
# 5                  Total  2020   44.587492  Europe          AUT   Austria
# 8                  Total  2019    2.626468  Europe          BGR  Bulgaria
# ...                  ...   ...         ...     ...          ...       ...
# 96947         Technology  2020    0.000000  Europe          EUM  Eumetsat
# 96948  Human Spaceflight  2020    0.000000  Europe          EUM  Eumetsat
# 96949    Launch vehicles  2020    0.000000  Europe          EUM  Eumetsat
# 96950     Space security  2020    0.000000  Europe          EUM  Eumetsat
# 96951              Other  2020    0.000000  Europe          EUM  Eumetsat
#
#       program_type      program_name     unit currency
# ...

# %%
df=budget[budget.value!=0]

# %%
budget_local_currency[budget_local_currency.value!=0]
# Out:
#                                          application  year       value  \
# 0                                              Total  2019  195.432000
# 1                                              Total  2020  171.600069
# 4                                              Total  2019   54.274739
# 5                                              Total  2020   44.587492
# 8                                              Total  2019    2.626468
# ...                                              ...   ...         ...
# 96704  EPS-Second Generation Preparation (EPS-SG PP)  2020  253.583333
# 96705                                            MTG  2020  136.583333
# 96706                                      Jason-2&3  2020    0.600000
# 96707                                       Jason-CS  2020   25.666667
# 96708                                           GMES  2020   38.833333
#
#        region country_code   country program_type      program_name     unit  \
# ...

# %%
budget_dollar[budget_dollar.value!=0]
# Out:
#                                          application  year       value  \
# 2                                              Total  2019  220.230630
# 3                                              Total  2020  193.374633
# 6                                              Total  2019   61.161734
# 7                                              Total  2020   50.245259
# 10                                             Total  2019    1.513415
# ...                                              ...   ...         ...
# 97210  EPS-Second Generation Preparation (EPS-SG PP)  2020  285.760864
# 97211                                            MTG  2020  153.914576
# 97212                                      Jason-2&3  2020    0.676135
# 97213                                       Jason-CS  2020   28.923545
# 97214                                           GMES  2020   43.760947
#
#        region country_code   country program_type      program_name     unit  \
# ...

# %%
budget_dollar[~(budget_dollar.country_code=='USA')].shape[0]-budget_local_currency.shape[0]
# Out:
# 484

# %%
budget_dollar[budget_dollar.country_code=='USA']
# Out:
#                application  year     value region country_code        country  \
# 94972  Internal operations  1999     0.000    NaN          USA  United States
# 94973   Telecommunications  1999    97.000    NaN          USA  United States
# 94974           Navigation  1999     0.000    NaN          USA  United States
# 94975    Earth Observation  1999  1414.000    NaN          USA  United States
# 94976          Meteorology  1999     0.000    NaN          USA  United States
# ...                    ...   ...       ...    ...          ...            ...
# 95473           Technology  2020  2056.072    NaN          USA  United States
# 95474    Human Spaceflight  2020     0.000    NaN          USA  United States
# 95475      Launch vehicles  2020  1836.804    NaN          USA  United States
# 95476       Space security  2020   725.491    NaN          USA  United States
# 95477                Other  2020   230.362    NaN          USA  United States
#
# ...

# %%
df_budget=budget_dollar[budget_dollar.value!=0]

# %%
df_fr=df_budget[df_budget.country_code=='FRA']

# %%
budget.program_name.value_counts(1)
# Out:
# National program    0.864803
# ESA                 0.123007
# Eumetsat            0.011738
# Others              0.000451
# Name: program_name, dtype: float64

# %%
df_fr[df_fr.year==2009]
# Out:
#                          application  year       value  region country_code  \
# 3518             Internal operations  2009   83.351509  Europe          FRA
# 3519              Telecommunications  2009   62.513631  Europe          FRA
# 3520                      Navigation  2009   88.908276  Europe          FRA
# 3521               Earth Observation  2009   94.465043  Europe          FRA
# 3522                     Meteorology  2009    9.724343  Europe          FRA
# 3523   Space Science and exploration  2009  126.416455  Europe          FRA
# 3524                      Technology  2009    0.001389  Europe          FRA
# 3525               Human Spaceflight  2009  140.308373  Europe          FRA
# 3526                 Launch vehicles  2009  343.130377  Europe          FRA
# 3527                  Space security  2009    2.778384  Europe          FRA
# 3528                           Other  2009    0.001389  Europe          FRA
# ...

# %%
df_fr_2=satellites[satellites['operator_query.country']=='France']

# %%
df_fr_2[df_fr_2['Launch year']==2009]
# Out:
#     satellite_Name  Launch year Launch status        Application  \
# 729      Helios 2B         2009      Launched  Earth Observation
# 730      SPIRALE 1         2009      Launched           Security
# 731      SPIRALE 2         2009      Launched           Security
#
#     operator_status operator_query.country global_regional_distribution  \
# 729         Defense                 France                       Europe
# 730         Defense                 France                       Europe
# 731         Defense                 France                       Europe
#
#     mass_range_kg price_range_m$
# 729  2001-5000 kg        >500 M$
# 730       <500 kg         <50 M$
# 731       <500 kg         <50 M$

# %%
df_budget.groupby(['country', 'year']).count().tail(60)
# Out:
#                     application  value  region  country_code  program_type  \
# country       year
# United States 2003           17     17       0            17            17
#               2004           16     16       0            16            16
#               2005           16     16       0            16            16
#               2006           17     17       0            17            17
#               2007           18     18       0            18            18
#               2008           18     18       0            18            18
#               2009           18     18       0            18            18
#               2010           18     18       0            18            18
#               2011           19     19       0            19            19
#               2012           19     19       0            19            19
#               2013           19     19       0            19            19
# ...

# %%
df.shape
# Out:
# (18612, 10)

# %%
df.head(20)
# Out:
#    application  year       value  region country_code         country  \
# 0        Total  2019  195.432000  Europe          BEL         Belgium
# 1        Total  2020  171.600069  Europe          BEL         Belgium
# 2        Total  2019  220.230630  Europe          BEL         Belgium
# 3        Total  2020  193.374633  Europe          BEL         Belgium
# 4        Total  2019   54.274739  Europe          AUT         Austria
# 5        Total  2020   44.587492  Europe          AUT         Austria
# 6        Total  2019   61.161734  Europe          AUT         Austria
# 7        Total  2020   50.245259  Europe          AUT         Austria
# 8        Total  2019    2.626468  Europe          BGR        Bulgaria
# 9        Total  2020    2.626468  Europe          BGR        Bulgaria
# 10       Total  2019    1.513415  Europe          BGR        Bulgaria
# 11       Total  2020    1.513415  Europe          BGR        Bulgaria
# ...

# %%
df.drop_duplicates()
# Out:
#                                          application  year       value  \
# 0                                              Total  2019  195.432000
# 1                                              Total  2020  171.600069
# 2                                              Total  2019  220.230630
# 3                                              Total  2020  193.374633
# 4                                              Total  2019   54.274739
# ...                                              ...   ...         ...
# 97210  EPS-Second Generation Preparation (EPS-SG PP)  2020  285.760864
# 97211                                            MTG  2020  153.914576
# 97212                                      Jason-2&3  2020    0.676135
# 97213                                       Jason-CS  2020   28.923545
# 97214                                           GMES  2020   43.760947
#
#        region country_code   country program_type      program_name     unit  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18612 entries, 0 to 97214
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   application   18612 non-null  object
#  1   year          18612 non-null  int64
#  2   value         18612 non-null  float64
#  3   region        17553 non-null  object
#  4   country_code  18612 non-null  object
#  5   country       18612 non-null  object
#  6   program_type  18612 non-null  object
#  7   program_name  18612 non-null  object
#  8   unit          18612 non-null  object
#  9   currency      18612 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 1.6+ MB

# %%
df.year.value_counts().sort_index()
# Out:
# 1999     437
# 2000     439
# 2001     473
# 2002     504
# 2003     575
# 2004     604
# 2005     642
# 2006     671
# 2007     680
# 2008     794
# 2009    1007
# 2010     929
# 2011    1046
# 2012     991
# 2013    1068
# 2014    1126
# 2015    1141
# 2016    1168
# 2017    1196
# 2018    1230
# 2019     930
# 2020     961
# Name: year, dtype: int64

# %%
satellites
# Out:
#      satellite_Name  Launch year           Launch status        Application  \
# 0            DMC-3A         2015                Launched  Earth Observation
# 1            DMC-3B         2015                Launched  Earth Observation
# 2            DMC-3C         2015                Launched  Earth Observation
# 3           SSTL-S1         2018                Launched  Earth Observation
# 4            VRSS-1         2012                Launched  Earth Observation
# ...             ...          ...                     ...                ...
# 2494      Yahsat-1B         2012                Launched            Telecom
# 2495    Thuraya 3+R         2024          To be launched            Telecom
# 2496       Al Yah 3         2018  Partial launch failure            Telecom
# 2497    Yahsat-1A+R         2026          To be launched            Telecom
# 2498    Yahsat-1B+R         2028          To be launched            Telecom
#
# ...

# %%
satellites.nunique()
# Out:
# satellite_Name                  2380
# Launch year                       20
# Launch status                      5
# Application                       10
# operator_status                    2
# operator_query.country            76
# global_regional_distribution       6
# mass_range_kg                      4
# price_range_m$                     5
# dtype: int64

# %%
satellites[satellites['operator_query.country']=='China'].head(20)
# Out:
#                        satellite_Name  Launch year   Launch status  \
# 0                              DMC-3A         2015        Launched
# 1                              DMC-3B         2015        Launched
# 2                              DMC-3C         2015        Launched
# 3                             SSTL-S1         2018        Launched
# 75                SJ-12 / Shi Jian 12         2010        Launched
# 76  Shiyan 4 (SY 4) / Tansuo 4 (TS 4)         2011        Launched
# 77                          Yinghuo-1         2011  Launch failure
# 78                                FN1         2012        Launched
# 79                SJ-9 / Shi Jian 9 A         2012        Launched
# 80                SJ-9 / Shi Jian 9 B         2012        Launched
# 81                               XY-1         2012        Launched
# 82                               HXMT         2017        Launched
# 83        SST (Solar space Telescope)         2019        Launched
# ...

# %%
satellites.Application.value_counts()
# Out:
# Earth Observation     705
# Telecom               607
# Security              253
# Navigation            251
# Manned spaceflight    183
# Technology            163
# Information           148
# Science               104
# Exploration            84
# In Orbit Servicing      1
# Name: Application, dtype: int64

# %%
satellites[satellites['price_range_m$']=='TBD']['Launch year'].value_counts().sort_index()
# Out:
# 2009    13
# 2010    11
# 2011    15
# 2012    11
# 2013    11
# 2014    10
# 2015    10
# 2016    10
# 2017     8
# 2018     8
# 2019    10
# 2020    11
# 2021     9
# 2022    13
# 2023    11
# 2024     8
# 2025     4
# 2026     3
# 2027     5
# 2028     2
# Name: Launch year, dtype: int64

# %%
satellites[satellites['price_range_m$']=='TBD']['Application'].value_counts()
# Out:
# Manned spaceflight    183
# Name: Application, dtype: int64

# %%
satellites[satellites['price_range_m$']=='TBD']['operator_query.country'].value_counts()
# Out:
# Russian Federation    117
# China                  28
# United States          20
# Japan                  13
# ESA                     5
# Name: operator_query.country, dtype: int64

# %%
satellites['Launch status'].value_counts()
# Out:
# To be launched            1267
# Launched                  1147
# Launch failure              42
# To be Launched              32
# Partial launch failure      11
# Name: Launch status, dtype: int64

# %%
satellites['Launch status'].replace({'To be Launched':'To be launched'}, inplace=True)

# %%
satellites['Launch status'].value_counts()
# Out:
# To be launched            1299
# Launched                  1147
# Launch failure              42
# Partial launch failure      11
# Name: Launch status, dtype: int64

# %%
satellites.Application.value_counts()
# Out:
# Earth Observation     705
# Telecom               607
# Security              253
# Navigation            251
# Manned spaceflight    183
# Technology            163
# Information           148
# Science               104
# Exploration            84
# In Orbit Servicing      1
# Name: Application, dtype: int64

# %%
satellites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2499 entries, 0 to 2498
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   satellite_Name                2499 non-null   object
#  1   Launch year                   2499 non-null   int64
#  2   Launch status                 2499 non-null   object
#  3   Application                   2499 non-null   object
#  4   operator_status               2499 non-null   object
#  5   operator_query.country        2499 non-null   object
#  6   global_regional_distribution  2499 non-null   object
#  7   mass_range_kg                 2499 non-null   object
#  8   price_range_m$                2499 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 175.8+ KB

# %%
satellites.global_regional_distribution.value_counts()
# Out:
# Asia                           1167
# Russia and Central Asia         501
# North America                   426
# Europe                          267
# Middle East and Africa           93
# Latin America and Caribbean      45
# Name: global_regional_distribution, dtype: int64

# %%
satellites.nunique()
# Out:
# satellite_Name                  2380
# Launch year                       20
# Launch status                      4
# Application                       10
# operator_status                    2
# operator_query.country            76
# global_regional_distribution       6
# mass_range_kg                      4
# price_range_m$                     5
# dtype: int64

# %% [markdown]
# # Conclusions
#
# ### Satellites
# * `satellite_Name`: unique id
# * `Launch year`: ok
# * `Launch status`: encoding 1 to 4 or dummies
# * `Application`: Encoding 1 to 10 or dummies
# * `operator_status`: 0 or 1 (can be civil 1/0)
# * `operator_query.country`: seems ok, have to change the name of the column
# * `global_regional_distribution`: change the name of the column
# * `mass_range_kg`: encoding 1 to 4
# * `price_range`: encoding 1 to 4 (and drop rows with TBD)
#
# ### Budget
# * Drop rows with value = 0
# * Drop rows where currency is different to USD
# * `application`: make it correspond to `Application` in `budget` file
# * `year`: ok
# * `value`: ok
# * `region`: can replace NaNs by NorAM
# * `country` and `country_code`: ok
# * `program_type`: same as operator_status (can ve civil 1/0)
# * `program_name`: ok
# * `unit`: always million (drop it)
# * `currency`: should be USD at the end

# %%
df_budget.unit.value_counts()
# Out:
# million    9516
# Name: unit, dtype: int64

# %%
df_budget.isna().sum()
# Out:
# application       0
# year              0
# value             0
# region          724
# country_code      0
# country           0
# program_type      0
# program_name      0
# unit              0
# currency          0
# dtype: int64

# %%
df_budget.head()
# Out:
#    application  year       value  region country_code   country program_type  \
# 2        Total  2019  220.230630  Europe          BEL   Belgium        Civil
# 3        Total  2020  193.374633  Europe          BEL   Belgium        Civil
# 6        Total  2019   61.161734  Europe          AUT   Austria        Civil
# 7        Total  2020   50.245259  Europe          AUT   Austria        Civil
# 10       Total  2019    1.513415  Europe          BGR  Bulgaria        Civil
#
#    program_name     unit currency
# 2           ESA  million      USD
# 3           ESA  million      USD
# 6           ESA  million      USD
# 7           ESA  million      USD
# 10          ESA  million      USD

# %%
df_budget.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9516 entries, 2 to 97214
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   application   9516 non-null   object
#  1   year          9516 non-null   int64
#  2   value         9516 non-null   float64
#  3   region        8792 non-null   object
#  4   country_code  9516 non-null   object
#  5   country       9516 non-null   object
#  6   program_type  9516 non-null   object
#  7   program_name  9516 non-null   object
#  8   unit          9516 non-null   object
#  9   currency      9516 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 817.8+ KB

# %%
df_budget.application.value_counts()
# Out:
# Earth Observation                                1417
# Internal operations                              1318
# Telecommunications                               1223
# Technology                                       1191
# Space Science and exploration                     900
# Meteorology                                       840
# Launch vehicles                                   709
# Navigation                                        597
# Human Spaceflight                                 482
# Space security                                    328
# Other                                             293
# Total                                              54
# Early warning                                      22
# USA classified program                             22
# European Polar System (EPS)                        22
# Meteosat Second Generation (MSG)                   22
# Meteosat Transition Program (MTP)                  19
# ...

# %%
df_budget.program_name.value_counts()
# Out:
# National program    6115
# ESA                 2923
# Eumetsat             474
# Others                 4
# Name: program_name, dtype: int64

# %%
df_budget[df_budget.program_name=='Others']
# Out:
#       application  year     value region country_code country program_type  \
# 18544       Other  1999  423840.0   Asia          JPN   Japan        Civil
# 18545       Other  2000  371200.0   Asia          JPN   Japan        Civil
# 18546       Other  2001  313120.0   Asia          JPN   Japan        Civil
# 18547       Other  2002  296000.0   Asia          JPN   Japan        Civil
#
#       program_name     unit currency
# 18544       Others  million      USD
# 18545       Others  million      USD
# 18546       Others  million      USD
# 18547       Others  million      USD

# %%
budget[budget.program_name=='Others']
# Out:
#       application  year     value region country_code country program_type  \
# 18038       Other  1999   48000.0   Asia          JPN   Japan        Civil
# 18039       Other  2000   40000.0   Asia          JPN   Japan        Civil
# 18040       Other  2001   38000.0   Asia          JPN   Japan        Civil
# 18041       Other  2002   37000.0   Asia          JPN   Japan        Civil
# 18042       Other  2003       0.0   Asia          JPN   Japan        Civil
# 18043       Other  2004       0.0   Asia          JPN   Japan        Civil
# 18044       Other  2005       0.0   Asia          JPN   Japan        Civil
# 18045       Other  2006       0.0   Asia          JPN   Japan        Civil
# 18046       Other  2007       0.0   Asia          JPN   Japan        Civil
# 18047       Other  2008       0.0   Asia          JPN   Japan        Civil
# 18048       Other  2009       0.0   Asia          JPN   Japan        Civil
# ...

# %%
df_budget.set_index('country').join(satellites.set_index('operator_query.country'))
# Out:
#                   application  year      value region country_code  \
# Algeria   Internal operations  2006  12.388739    MEA          DZA
# Algeria   Internal operations  2006  12.388739    MEA          DZA
# Algeria   Internal operations  2006  12.388739    MEA          DZA
# Algeria   Internal operations  2006  12.388739    MEA          DZA
# Algeria   Internal operations  2006  12.388739    MEA          DZA
# ...                       ...   ...        ...    ...          ...
# Zimbabwe    Earth Observation  2018   0.800000    MEA          ZWE
# Zimbabwe  Internal operations  2019   0.500000    MEA          ZWE
# Zimbabwe    Earth Observation  2019   0.800000    MEA          ZWE
# Zimbabwe  Internal operations  2020   0.500000    MEA          ZWE
# Zimbabwe    Earth Observation  2020   0.840000    MEA          ZWE
#
#          program_type      program_name     unit currency satellite_Name  \
# Algeria         Civil  National program  million      USD       Alsat-2A
# ...

# %%
budget.year.agg(['min', 'max'])
# Out:
# min    1999
# max    2020
# Name: year, dtype: int64

# %%
budget.year.min()
